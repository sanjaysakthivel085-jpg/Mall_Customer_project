# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('Mall_Customers.csv')

data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income  Spending Score
# 0           1    Male   19             15              39
# 1           2    Male   21             15              81
# 2           3  Female   20             16               6
# 3           4  Female   23             16              77
# 4           5  Female   31             17              40

# %%
print(data.shape)

data.info()
# Out:
# (50, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      50 non-null     int64
#  1   Gender          50 non-null     object
#  2   Age             50 non-null     int64
#  3   Annual Income   50 non-null     int64
#  4   Spending Score  50 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %%
X = data[['Annual Income', 'Spending Score']]

X.head()
# Out:
#    Annual Income  Spending Score
# 0             15              39
# 1             15              81
# 2             16               6
# 3             16              77
# 4             17              40

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(8,5))
plt.plot(range(1,11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(
    n_clusters=5,
    random_state=42,
    n_init=10
)

y_kmeans = kmeans.fit_predict(X)

# %%
data['Cluster'] = y_kmeans

data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income  Spending Score  Cluster
# 0           1    Male   19             15              39        3
# 1           2    Male   21             15              81        4
# 2           3  Female   20             16               6        1
# 3           4  Female   23             16              77        4
# 4           5  Female   31             17              40        3

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    X['Annual Income'],
    X['Spending Score'],
    c=y_kmeans,
    cmap='rainbow'
)

plt.scatter(
    kmeans.cluster_centers_[:,0],
    kmeans.cluster_centers_[:,1],
    s=300,
    color='black',
    marker='X'
)

plt.title('Customer Segmentation')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')

plt.show()

# %%
plt.savefig('Mall_Customer.png')

# %%
data.groupby('Cluster').mean(numeric_only=True)
# Out:
#          CustomerID        Age  Annual Income  Spending Score
# Cluster
# 0         42.600000  33.400000      37.200000       57.800000
# 1         20.166667  48.750000      25.000000        9.583333
# 2         24.333333  26.333333      27.000000       93.666667
# 3         29.692308  39.615385      30.307692       34.615385
# 4         20.571429  24.214286      24.714286       75.571429

# %%
data.to_csv('Mall_Customer_result.csv', index=False)

# %%
from google.colab import files

files.download('Mall_Customer_result.csv')

# %%
from google.colab import files

files.download('Mall_Customer.png')
